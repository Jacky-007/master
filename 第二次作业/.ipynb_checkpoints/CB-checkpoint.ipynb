# %%
# 代码说明：
# 基于内容的推荐算法的具体实现

import math
import numpy as np
import pandas as pd

# %%
# 创建用户画像
# 参数说明：
# data_array: 所有用户对于其所看过的节目的评分矩阵 data_array = [[2, 0, 0, 1.1, ...], [0, 0, 1.1, ...], ...]
# users_profiles = {user1:{'label1':1.1, 'label2': 0.5, 'label3': 0.0, ...}, user2:{...}...}
def createUsersProfiles(data_array, users_names, items_names, labels_names, items_profiles):

    users_profiles = {}

    # 计算每个用户对所看过的所有节目的平均隐性评分
    # users_average_scores_list = [1.2, 2.2, 4.3,...]
    users_average_scores_list = []

    # 统计每个用户所看过的节目（不加入隐性评分信息）
    # items_users_saw = {user1:[item1, item3, item5], user2:[...],...}
    items_users_saw = {}

    # 统计每个用户所看过的节目及评分
    # items_users_saw_scores = {user1:[[item1, 1.1], [item2, 4.1]], user2:...}
    items_users_saw_scores = {}
    for i in range(len(users_names)):

        items_users_saw_scores[users_names[i]] = []
        items_users_saw[users_names[i]] = []
        count = 0
        sum1 = 0.0
        for j in range(len(items_names)):

            # 用户对该节目隐性评分为正，表示真正看过该节目
            if data_array[i][j] > 0:
                items_users_saw[users_names[i]].append(items_names[j])
                items_users_saw_scores[users_names[i]].append([items_names[j], data_array[i][j]])
                count += 1
                sum1 += data_array[i][j]
        if count == 0:
            users_average_scores_list.append(0)
        else:
            users_average_scores_list.append(sum1 / count)

    for i in range(len(users_names)):

        users_profiles[users_names[i]] = {}

        for j in range(len(labels_names)):
            count = 0
            score = 0.0
            
            print(items_users_saw_scores)
            for item in items_users_saw_scores[users_names[i]]:

                # 参数：
                # 用户user1对于类型label1的隐性评分: user1_score_to_label1
                # 用户user1对于其看过的含有类型label1的节目item i 的评分: score_to_item i
                # 用户user1对其所看过的所有节目的平均评分: user1_average_score
                # 用户user1看过的节目总数: items_count

                # 公式： user1_score_to_label1 = Sigma(score_to_item i - user1_average_score)/items_count

                # 该节目含有特定标签labels_names[j]
                if items_profiles[item[0]][labels_names[j]] > 0:
                    print(score,'123',item[1])
                    score += (item[1] - users_average_scores_list[i])
                    count += 1
            # 如果求出的值太小，直接置0
            if abs(score) < 1e-6:
                score = 0.0
            if count == 0:
                result = 0.0
            else:
                result = score / count

            users_profiles[users_names[i]][labels_names[j]] = result

    return (users_profiles, items_users_saw)

# %%
# 创建节目画像
# 参数说明：
# items_profiles = {item1:{'label1':1, 'label2': 0, 'label3': 0, ...}, item2:{...}...}
def createItemsProfiles(data_array, labels_names, items_names):

    items_profiles = {}

    for i in range(len(items_names)):

        items_profiles[items_names[i]] = {}

        for j in range(len(labels_names)):
            items_profiles[items_names[i]][labels_names[j]] = data_array[i][j]

    return items_profiles

# %%
# 计算用户画像向量与节目画像向量的距离（相似度）
# 向量相似度计算公式：
# cos(user, item) = sigma_ui/sqrt(sigma_u * sigma_i)

# 参数说明：
# user_profile: 某一用户user的画像 user = {'label1':1.1, 'label2': 0.5, 'label3': 0.0, ...}
# item: 某一节目item的画像 item = {'label1':1, 'label2': 0, 'label3': 0, ...}
# labels_names: 所有类型名
def calCosDistance(user, item, labels_names):

    sigma_ui = 0.0
    sigma_u = 0.0
    sigma_i = 0.0

    for label in labels_names:
        sigma_ui += user[label] * item[label]
        sigma_u += (user[label] * user[label])
        sigma_i += (item[label] * item[label])

    if sigma_u == 0.0 or sigma_i == 0.0:  # 若分母为0，相似度为0
        return 0

    return sigma_ui/math.sqrt(sigma_u * sigma_i)

# %%
# 基于内容的推荐算法：
# 借助特定某个用户user的画像user_profile和备选推荐节目集的画像items_profiles，通过计算向量之间的相似度得出推荐节目集

# 参数说明：
# user_profile: 某一用户user的画像 user_profile = {'label1':1.1, 'label2': 0.5, 'label3': 0.0, ...}
# items_profiles: 备选推荐节目集的节目画像: items_profiles = {item1:{'label1':1, 'label2': 0, 'label3': 0}, item2:{...}...}
# items_names: 备选推荐节目集中的所有节目名
# labels_names: 所有类型名
# items_user_saw: 用户user看过的节目

def contentBased(user_profile, items_profiles, items_names, labels_names, items_user_saw):

    # 对于用户user的推荐节目集为 recommend_items = [[节目名, 该节目画像与该用户画像的相似度], ...]
    recommend_items = []

    for i in range(len(items_names)):
        # 从备选推荐节目集中的选择用户user没有看过的节目
        if items_names[i] not in items_user_saw:
            recommend_items.append([items_names[i], calCosDistance(user_profile, items_profiles[items_names[i]], labels_names)])

    # 将推荐节目集按相似度降序排列
    recommend_items.sort(key=lambda item: item[1], reverse=True)

    return recommend_items

# %%
# 输出推荐给该用户的节目列表
# max_num:最多输出的推荐节目数
def printRecommendedItems(recommend_items_sorted, max_num):
    count = 0
    for item, degree in recommend_items_sorted:
        print("节目名：%s， 推荐指数：%f" % (item, degree))
        count += 1
        if count == max_num:
            break

# %%
#一些超参数
all_labels = ['sports','video','kids','middleeast','travel','finance','games','news', 'health', 'weather', 'foodanddrink', 'movies', 'autos', 'lifestyle', 'music', 'tv', 'entertainment']

# %%
df2 = pd.read_excel("news01.xlsx")
(m2, n2) = df2.shape
data_array2 = np.array(df2.iloc[:m2 + 1, 1:])
# 按照"所有用户看过的节目及所属类型的01矩阵"的列序排列的所有用户观看过的节目名称
items_users_saw_names2 = np.array(df2.iloc[:m2 + 1, 0]).tolist()

# 为用户看过的节目建立节目画像
items_users_saw_profiles = createItemsProfiles(data_array2, all_labels, items_users_saw_names2)
# Out:
# ['N18955', 'N61837', 'N53526', 'N38324', 'N2073', 'N11429', 'N49186', 'N2131', 'N59295', 'N24510', 'N59883', 'N9721', 'N60905', 'N16587', 'N28361', 'N18680', 'N55610', 'N35621', 'N22850', 'N58173', 'N29120', 'N9786', 'N46481', 'N47705', 'N1834', 'N3574', 'N42474', 'N64498', 'N59538', 'N7517', 'N63665', 'N26094', 'N59469', 'N11649', 'N15926', 'N43620', 'N60603', 'N40078', 'N61409', 'N22486', 'N46013', 'N50643', 'N60723', 'N63175', 'N282', 'N33434', 'N8795', 'N43647', 'N40690', 'N41835', 'N8071', 'N49265', 'N5124', 'N42777', 'N41387', 'N41106', 'N37243', 'N20139', 'N9680', 'N35518', 'N60434', 'N48239', 'N49389', 'N40045', 'N43946', 'N14555', 'N10836', 'N24798', 'N64668', 'N27435', 'N30756', 'N3395', 'N21802', 'N53133', 'N30702', 'N14538', 'N37188', 'N30953', 'N10886', 'N52386', 'N30389', 'N25540', 'N18066', 'N51343', 'N6982', 'N60774', 'N37129', 'N64723', 'N8105', 'N40494', 'N15839', 'N19163', 'N60852', 'N61864', 'N36064', 'N35788', 'N22993', 'N61167', 'N27190', 'N9035', 'N19651', 'N30286', 'N22957', 'N63006', 'N39205', 'N5159', 'N43944', 'N47685', 'N44720', 'N55024', 'N41277', 'N52683', 'N8185', 'N42921', 'N1358', 'N39817', 'N17573', 'N23182', 'N34169', 'N51340', 'N59256', 'N46021', 'N13855', 'N16556', 'N22679', 'N61044', 'N30412', 'N18393', 'N11663', 'N55435', 'N39173', 'N33874', 'N50397', 'N44661', 'N41976', 'N54727', 'N4938', 'N11683', 'N31442', 'N47214', 'N63975', 'N31402', 'N61358', 'N48632', 'N27214', 'N51426', 'N41013', 'N19888', 'N45191', 'N61396', 'N17364', 'N19950', 'N47600', 'N32289', 'N35318', 'N11360', 'N48716', 'N6228', 'N24417', 'N59891', 'N4814', 'N30236', 'N64593', 'N2559', 'N54542', 'N30290', 'N51844', 'N7992', 'N49374', 'N14176', 'N60584', 'N26921', 'N10', 'N21982', 'N61914', 'N21253', 'N24905', 'N65207', 'N35616', 'N23386', 'N48579', 'N43484', 'N54140', 'N63556', 'N52248', 'N59794', 'N38866', 'N7458', 'N15483', 'N62736', 'N35080', 'N19146', 'N17041', 'N56515', 'N48072', 'N63237', 'N18287', 'N59435', 'N31161', 'N30312', 'N37032', 'N29866', 'N59268', 'N8691', 'N30868', 'N50460', 'N56618', 'N59021', 'N36464', 'N38308', 'N12440', 'N27334', 'N42716', 'N39638', 'N24900', 'N18770', 'N9947', 'N25205', 'N1144', 'N530', 'N61681', 'N59709', 'N57930', 'N1579', 'N36152', 'N9013', 'N15651', 'N15999', 'N63682', 'N37581', 'N53546', 'N55797', 'N41869', 'N13882', 'N6258', 'N27641', 'N36534', 'N42932', 'N50246', 'N60798', 'N37423', 'N23937', 'N43734', 'N29601', 'N53376', 'N11593', 'N23874', 'N3565', 'N6293', 'N61203', 'N9774', 'N1955', 'N10538', 'N20833', 'N59874', 'N19513', 'N3649', 'N6632', 'N28561', 'N25024', 'N25602', 'N33593', 'N41208', 'N61178', 'N4015', 'N49154', 'N58146', 'N34122', 'N3528', 'N39809', 'N1810', 'N14042', 'N12081', 'N27287', 'N58035', 'N52529', 'N16077', 'N27063', 'N7348', 'N49134', 'N15891', 'N34722', 'N5599', 'N54182', 'N54429', 'N49830', 'N36911', 'N14606', 'N49369', 'N64413', 'N37414', 'N27137', 'N9880', 'N34406', 'N9', 'N15254', 'N33161', 'N55248', 'N7771', 'N30781', 'N31552', 'N30344', 'N30632', 'N19490', 'N48774', 'N18097', 'N61891', 'N7373', 'N335', 'N39751', 'N28035', 'N49198', 'N62084', 'N5754', 'N60941', 'N20723', 'N35774', 'N43916', 'N20513', 'N8798', 'N10376', 'N7951', 'N60467', 'N58332', 'N20849', 'N18885', 'N50573', 'N21041', 'N16032', 'N21936', 'N44133', 'N61079', 'N55625', 'N13358', 'N5682', 'N46832', 'N44959', 'N17286', 'N56461', 'N7362', 'N9972', 'N20743', 'N21383', 'N14534', 'N30012', 'N33942', 'N10122', 'N32006', 'N17651', 'N9900', 'N46688', 'N6536', 'N3570', 'N7182', 'N50742', 'N25631', 'N19028', 'N51601', 'N11161', 'N47866', 'N32907', 'N55111', 'N49505', 'N56590', 'N45908', 'N42669', 'N54064', 'N46428', 'N4021', 'N59255', 'N17430', 'N25604', 'N59271', 'N13', 'N53707', 'N59418', 'N34242', 'N16928', 'N63651', 'N37957', 'N33458', 'N47315', 'N18854', 'N48344', 'N27350', 'N61084', 'N62073', 'N228', 'N12987', 'N20818', 'N31633', 'N4489', 'N12676', 'N42607', 'N31341', 'N18012', 'N45075', 'N32935', 'N33521', 'N50208', 'N2346', 'N42908', 'N47966', 'N55337', 'N42736', 'N63891', 'N39336', 'N33 ...

# %%
items_users_saw_profiles
# Out:
# {'N18955': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N61837': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N53526': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N38324': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N2073': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N11429': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N49186': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 1,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N2131': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N59295': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N24510': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 1},
#  'N59883': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N9721': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N60905': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N16587': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N28361': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N18680': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N55610': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N35621': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 1},
#  'N22850': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 1,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N58173': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N29120': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N9786': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N46481': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N47705': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 1,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N1834': {'sports': 0,
#   'video': 1,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N3574': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N42474': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N64498': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N59538': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N7517': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N63665': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N26094': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N59469': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N11649': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 1,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N15926': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N43620': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N60603': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 1},
#  'N40078': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 1,
#   'entertainment': 0},
#  'N61409': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N22486': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N46013': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N50643': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 1,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N60723': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N63175': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N282': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N33434': {'sports': 0,
#   'video': 1,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N8795': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N43647': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N40690': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N41835': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N8071': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N49265': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N5124': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N42777': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N41387': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 1,
#   'entertainment': 0},
#  'N41106': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N37243': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 1,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N20139': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N9680': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 1,
#   'entertainment': 0},
#  'N35518': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N60434': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N48239': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N49389': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N40045': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 1,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N43946': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 1,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N14555': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N10836': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N24798': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N64668': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N27435': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N30756': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 1},
#  'N3395': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 1,
#   'entertainment': 0},
#  'N21802': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N53133': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N30702': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N14538': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N37188': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N30953': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N10886': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N52386': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N30389': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 1},
#  'N25540': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 1,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N18066': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N51343': {'sports': 0,
#   'video': 1,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N6982': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N60774': {'sports': 0,
#   'video': 1,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N37129': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 1,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N64723': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N8105': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N40494': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N15839': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N19163': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N60852': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 1,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N61864': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N36064': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 1,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N35788': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N22993': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 1,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N61167': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 1,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N27190': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N9035': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N19651': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N30286': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N22957': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N63006': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 1,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N39205': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N5159': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 1,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N43944': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 1,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N47685': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N44720': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N55024': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N41277': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N52683': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N8185': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N42921': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N1358': {'sports': 0,
#   'video': 1,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N39817': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N17573': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N23182': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 1,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N34169': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N51340': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N59256': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N46021': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N13855': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N16556': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N22679': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N61044': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N30412': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N18393': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N11663': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N55435': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N39173': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 1,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N33874': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N50397': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N44661': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N41976': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N54727': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N4938': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 1,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N11683': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 1,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N31442': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N47214': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N63975': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N31402': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N61358': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N48632': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 1,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N27214': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N51426': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 1,
#   'tv': 0,
#   'entertainment': 0},
#  'N41013': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N19888': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N45191': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N61396': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N17364': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N19950': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N47600': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N32289': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N35318': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N11360': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N48716': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 1,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N6228': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 1,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N24417': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N59891': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N4814': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N30236': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N64593': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N2559': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 1,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N54542': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N30290': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N51844': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N7992': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 1,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N49374': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N14176': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N60584': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N26921': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N10': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N21982': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
# ...
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 1,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N34721': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N12100': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N19220': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N13746': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N64403': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 1,
#   'tv': 0,
#   'entertainment': 0},
#  'N37983': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N45955': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N60379': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N49821': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 1,
#   'entertainment': 0},
#  'N31585': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 1,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N7503': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N11735': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N42785': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N3712': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 1,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N41882': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N35000': {'sports': 0,
#   'video': 1,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N53688': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N39417': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N47868': {'sports': 0,
#   'video': 1,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N50884': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 1,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N45354': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N56852': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N55403': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N14358': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 1,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N122': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 1,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N45847': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 1,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N29695': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N50048': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N13292': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N52221': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N2487': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 1,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N6529': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N54405': {'sports': 0,
#   'video': 1,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N40490': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 1,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N48120': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 1,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N50187': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N10839': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N19931': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N16495': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N17771': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N8928': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 1,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N53224': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 1,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N52018': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N40091': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N36682': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N44047': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N31524': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N13104': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 1,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N39932': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N24343': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N54822': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 1,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N28861': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 1,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N40447': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 1,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N56233': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N62372': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 1,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N36300': {'sports': 0,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 1,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  'N8763': {'sports': 1,
#   'video': 0,
#   'kids': 0,
#   'middleeast': 0,
#   'travel': 0,
#   'finance': 0,
#   'games': 0,
#   'news': 0,
#   'health': 0,
#   'weather': 0,
#   'foodanddrink': 0,
#   'movies': 0,
#   'autos': 0,
#   'lifestyle': 0,
#   'music': 0,
#   'tv': 0,
#   'entertainment': 0},
#  ...}

# %%
df = pd.read_csv(r'test\test.tsv',sep = '\t')
(m, n) = df.shape
df
# Out:
#          Uid                    Date  \
# 0     U21693   11/15/2019 6:52:40 AM
# 1     U25377   11/15/2019 5:44:39 AM
# 2     U30939   11/15/2019 6:54:55 AM
# 3     U26167   11/15/2019 8:58:13 PM
# 4     U77000   11/15/2019 8:16:06 AM
# ...      ...                     ...
# 1995  U27889   11/15/2019 5:58:17 PM
# 1996  U58461   11/15/2019 9:12:18 AM
# 1997  U83646   11/15/2019 5:35:07 AM
# 1998  U23840   11/15/2019 6:32:45 AM
# 1999  U34517  11/15/2019 11:57:35 AM
#
#                                                 History  \
# 0            N770 N50047 N4020 N306 N64467 N4607 N41449
# 1     N24302 N6385 N49997 N33371 N47121 N11917 N5209...
# 2     N55743 N47175 N5445 N18285 N54454 N54960 N138 ...
# 3                           N55189 N23653 N43142 N42620
# 4     N23249 N18845 N32742 N48755 N52551 N47508 N122...
# ...                                                 ...
# 1995  N38939 N55189 N848 N64554 N26288 N34419 N38390...
# 1996                                       N53883 N8143
# 1997  N55189 N45729 N43369 N24127 N39041 N61471 N566...
# 1998  N995 N61319 N8845 N32203 N18030 N18094 N22420 ...
# 1999  N56461 N26531 N47077 N18247 N22570 N31686 N520...
#
#                                              Impression
# 0     N11930 N7419 N60747 N41946 N7342 N23513 N31958...
# 1     N34633 N60658 N41946 N23767 N5051 N16854 N5732...
# 2     N42844 N20187 N35216 N6638 N13408 N20036 N3678...
# 3                    N56080 N54562 N52492 N12409 N14802
# 4     N36779 N5051 N36786 N65145 N58264 N46976 N3195...
# ...                                                 ...
# 1995  N53572 N62949 N31910 N56080 N46749 N11930 N512...
# 1996                                      N20036 N36779
# 1997                        N20036 N23513 N32536 N36779
# 1998  N20036 N35216 N31958 N6638 N36779 N32536 N5940...
# 1999  N29862 N64264 N6400 N21679 N50775 N24802 N5472...
#
# [2000 rows x 4 columns]

# %%
#函数说明：输入data_array，行(m),获取该行的新闻标题列表，p = 3的时候获取history，p = 4的时候获取impression
def title(data_array,m,p):
    s = str(data_array[m][p])
    s1 = s.split(' ')
    return s1

# %%
# 按顺序提取所有用户名
all_user_names = np.array(df.iloc[:m+1, 0])[1:]

# %%
df2 = pd.read_csv(r'test\test_news.tsv',sep = '\t')
(m1,n1) = df2.shape
# 按顺序提取所有新闻代号
all_items_names = np.array(df2.iloc[:m1+1, 0])[1:]
items_num = len(all_items_names)
all_items_names1 = all_items_names.tolist()

# %%
data_array = np.array(df.iloc[:m+1,:])
data_array
# Out:
# array([['U21693', '11/15/2019 6:52:40 AM',
#         'N770 N50047 N4020 N306 N64467 N4607 N41449',
#         'N11930 N7419 N60747 N41946 N7342 N23513 N31958 N62318 N5940 N36940 N36779 N43646 N51793 N6916 N53242 N30290 N23767 N42844 N42233 N35216 N48487 N13408 N10423 N46976 N42767 N13865 N46162 N32536 N20187 N36786 N27738 N27057 N24109 N6638 N40656 N20036 N13556 N42670'],
#        ['U25377', '11/15/2019 5:44:39 AM',
#         'N24302 N6385 N49997 N33371 N47121 N11917 N52096 N10646 N60595 N10059 N54932 N37669 N35637 N28467 N4830 N11701 N11701 N4830 N35637 N59231 N17176 N14340 N54099 N21260 N53520 N13669 N2939 N54959 N58715 N29249 N58091 N21851 N19638 N48492 N13605 N47525 N55310 N61681 N39235 N59496 N63239 N49159 N61681 N64049 N44598 N61018 N4060 N63633 N38865 N36691 N7158 N43132 N27424 N40704 N43132 N26045 N8031 N28144 N49728 N43903 N61681 N23157 N3057 N17165 N23157 N28550 N61388 N27830 N49325 N59359 N40692 N33073 N32836 N59691 N16480 N26758 N5344 N43380 N30681 N38961 N5345 N6778 N48356 N38256 N20294 N7527 N24795 N55550 N58283 N27186 N30924 N17099 N40199 N19473 N33263 N16655 N21164 N26364 N53895 N49475 N32069 N25378 N16284 N11804 N16812 N1939 N7877 N56527 N18725 N1247 N63074 N38962 N18321 N40509 N6113 N14584 N23009 N30167 N59020',
#         'N34633 N60658 N41946 N23767 N5051 N16854 N57327 N32237 N49712 N32708 N30290 N2852 N47572 N7342 N55084 N20036 N40403 N11930 N42950 N28413'],
#        ['U30939', '11/15/2019 6:54:55 AM',
#         'N55743 N47175 N5445 N18285 N54454 N54960 N138 N63180 N31801 N23105 N36557 N27919 N306 N43142 N25965 N60622 N6884 N35255 N2231 N52551 N63573 N32004 N4607 N46846 N51705 N10933 N37814 N20575 N35671',
#         'N42844 N20187 N35216 N6638 N13408 N20036 N36786 N36779 N53242 N5940 N13556 N30290'],
#        ...,
#        ['U83646', '11/15/2019 5:35:07 AM',
#         'N55189 N45729 N43369 N24127 N39041 N61471 N56692 N52718 N46978 N64408 N10715 N16233 N32483 N19643 N28419 N65128 N35505 N37599 N39117 N31983 N48256 N38668 N26727 N12197 N57886 N62565 N40344 N41840 N46844 N33969 N44292 N52589 N42801 N59156 N39235 N18094 N9311 N17796 N9226 N43132 N46392 N9120 N59704 N50328 N49319 N38367 N45491 N19823 N10331 N34004 N36650 N52883 N64756 N23249 N63411 N28425 N61388 N32674 N45954 N14947 N64395 N30842 N31709 N10053 N52536 N56399 N7062 N38701 N26815 N26580 N35462 N23539 N31801 N54225 N13716 N44551 N30160 N306 N46229 N3086 N43142 N62714 N7172 N14040 N13138 N31248 N25450 N47308 N14257 N28311 N22997 N50087 N8277 N62348 N23518 N2078 N48715 N19495 N32004 N41218 N61972 N5886 N55911 N33163 N56086 N23958 N55497 N31599 N57187 N2003 N54077 N18069 N5104 N37091 N7327 N22471 N26319 N10359 N41652 N55434 N30167 N37322 N8170 N37322 N60364 N44737 N53095 N40785 N4815 N53008 N53017 N48718 N15855 N46845 N17340 N28091 N17350',
#         'N20036 N23513 N32536 N36779'],
#        ['U23840', '11/15/2019 6:32:45 AM',
#         'N995 N61319 N8845 N32203 N18030 N18094 N22420 N60938 N27106 N52482 N64074 N45794 N53531 N33976 N38967 N62352 N36734 N46513 N50126 N47575 N15046 N48497 N43175 N4593 N477 N17070 N22499 N60184 N23554 N45954 N24578 N9319 N33092 N56515 N18378 N20057 N54842 N43376 N18285 N24243 N54225 N54655 N27919 N47672 N43142 N11405 N42620 N46671 N6102 N54933 N52551 N6768 N9674 N26364 N61363 N13798 N3259 N26825 N14349 N29561 N90 N8285 N13182 N49792 N51992 N50941 N601 N46473 N54891 N6218 N63810 N16344 N9103 N7328 N53017 N23196 N59451',
#         'N20036 N35216 N31958 N6638 N36779 N32536 N5940 N46976 N23513'],
#        ['U34517', '11/15/2019 11:57:35 AM',
#         'N56461 N26531 N47077 N18247 N22570 N31686 N52097 N54582 N21553 N33314 N55846 N51111 N51998 N21623 N25971 N56037 N15254 N16215 N14644 N10078 N58227 N8953 N19048 N64408 N20335 N4614 N13298 N59754 N17176 N28296 N57255 N40628 N6290 N363 N63906 N54959 N13480 N21429 N29249 N59496 N6156 N9899 N53052 N14000 N51238 N36792 N48124 N33976 N8834 N40838 N45794 N62703 N32110 N5486 N40406 N34536 N42359 N1169 N697 N58744 N43175 N848 N36019 N37920 N51385 N54580 N38367 N16617 N34178 N1506 N17070 N52408 N35290 N44680 N57812 N27759 N27820 N27759 N52621 N10629 N33920 N57958 N48592 N7943 N12349 N6321 N48120 N24591 N56290 N58200 N55166 N13912 N63526 N38701 N20057 N34415 N29522 N37304 N26210 N31801 N6285 N62445 N62940 N29599 N10062 N35321 N4526 N14952 N40640 N30160 N41375 N26000 N54469 N13138 N52050 N36888 N62209 N14888 N63688 N51464 N17892 N11057 N44347 N22270 N31099 N37159 N62058 N61181 N47763 N5390 N16922 N51330 N6842 N31647 N2912 N167 N30765 N9674 N38105 N32291 N49608 N21526 N12761 N51992 N8258 N60212 N50941 N60543 N1446 N22260 N46966 N20567 N57464 N21899 N8061 N4970 N26165 N5019 N13337 N1969 N44278 N17109 N55714 N8878 N39798 N33532 N60984 N26179 N20139 N35276 N24913 N30978 N30864 N26617 N31850 N24365 N26526 N21428 N52307 N33981 N29510 N19968 N5791 N46231 N15676 N62391 N29069 N2735 N59143 N23784',
#         'N29862 N64264 N6400 N21679 N50775 N24802 N5472 N53572']],
#       dtype=object)

# %%
for i in range(len(all_user_names)):

    # 每个新闻的01向量
    vector = [0] * items_num
    #news_names_list = str(data_array[i][0]).split(" ")
    news_names_list = title(data_array,i,3)
    for j in range(len(news_names_list)):
        if (news_names_list[j] in all_items_names1):
            location = all_items_names1.index(news_names_list[j])
            vector[location] += 1

    data_to_be_written.append(vector)

data_to_be_written = np.transpose(data_to_be_written)
# 将01矩阵写入“news01.xlsx”
df = pd.DataFrame(data_to_be_written, index=all_items_names, columns=all_users_names)
df.to_excel("news_user_saw.xlsx")

# %%
'''
vector = [0] * items_num
news_names_list = title(data_array,0,3)
for j in range(len(news_names_list)):
        if (news_names_list[j] in all_items_names1):
            location = all_items_names1.index(news_names_list[j])
            vector[location] += 1
data_array1 = np.array([vector])
'''

# %%
items_users_saw_names1 = title(data_array,0,3)
items_saw_number = len(items_users_saw_names1)
items_users_saw_names1
# Out:
# ['N11930',
#  'N7419',
#  'N60747',
#  'N41946',
#  'N7342',
#  'N23513',
#  'N31958',
#  'N62318',
#  'N5940',
#  'N36940',
#  'N36779',
#  'N43646',
#  'N51793',
#  'N6916',
#  'N53242',
#  'N30290',
#  'N23767',
#  'N42844',
#  'N42233',
#  'N35216',
#  'N48487',
#  'N13408',
#  'N10423',
#  'N46976',
#  'N42767',
#  'N13865',
#  'N46162',
#  'N32536',
#  'N20187',
#  'N36786',
#  'N27738',
#  'N27057',
#  'N24109',
#  'N6638',
#  'N40656',
#  'N20036',
#  'N13556',
#  'N42670']

# %%
vector = [1] * items_saw_number
data_array1 = np.array([vector])

# %%
# 建立用户画像users_profiles和用户看过的节目集items_users_saw
(users_profiles, items_users_saw) = createUsersProfiles(data_array1, ['U21693'], items_users_saw_names1, all_labels, items_users_saw_profiles)
# Out:
# {'U21693': [['N11930', 1], ['N7419', 1], ['N60747', 1], ['N41946', 1], ['N7342', 1], ['N23513', 1], ['N31958', 1], ['N62318', 1], ['N5940', 1], ['N36940', 1], ['N36779', 1], ['N43646', 1], ['N51793', 1], ['N6916', 1], ['N53242', 1], ['N30290', 1], ['N23767', 1], ['N42844', 1], ['N42233', 1], ['N35216', 1], ['N48487', 1], ['N13408', 1], ['N10423', 1], ['N46976', 1], ['N42767', 1], ['N13865', 1], ['N46162', 1], ['N32536', 1], ['N20187', 1], ['N36786', 1], ['N27738', 1], ['N27057', 1], ['N24109', 1], ['N6638', 1], ['N40656', 1], ['N20036', 1], ['N13556', 1], ['N42670', 1]]}
# 0.0 123 1
# 0.0 123 1
# 0.0 123 1
# 0.0 123 1
# 0.0 123 1
# 0.0 123 1
# {'U21693': [['N11930', 1], ['N7419', 1], ['N60747', 1], ['N41946', 1], ['N7342', 1], ['N23513', 1], ['N31958', 1], ['N62318', 1], ['N5940', 1], ['N36940', 1], ['N36779', 1], ['N43646', 1], ['N51793', 1], ['N6916', 1], ['N53242', 1], ['N30290', 1], ['N23767', 1], ['N42844', 1], ['N42233', 1], ['N35216', 1], ['N48487', 1], ['N13408', 1], ['N10423', 1], ['N46976', 1], ['N42767', 1], ['N13865', 1], ['N46162', 1], ['N32536', 1], ['N20187', 1], ['N36786', 1], ['N27738', 1], ['N27057', 1], ['N24109', 1], ['N6638', 1], ['N40656', 1], ['N20036', 1], ['N13556', 1], ['N42670', 1]]}
# 0.0 123 1
# {'U21693': [['N11930', 1], ['N7419', 1], ['N60747', 1], ['N41946', 1], ['N7342', 1], ['N23513', 1], ['N31958', 1], ['N62318', 1], ['N5940', 1], ['N36940', 1], ['N36779', 1], ['N43646', 1], ['N51793', 1], ['N6916', 1], ['N53242', 1], ['N30290', 1], ['N23767', 1], ['N42844', 1], ['N42233', 1], ['N35216', 1], ['N48487', 1], ['N13408', 1], ['N10423', 1], ['N46976', 1], ['N42767', 1], ['N13865', 1], ['N46162', 1], ['N32536', 1], ['N20187', 1], ['N36786', 1], ['N27738', 1], ['N27057', 1], ['N24109', 1], ['N6638', 1], ['N40656', 1], ['N20036', 1], ['N13556', 1], ['N42670', 1]]}
# {'U21693': [['N11930', 1], ['N7419', 1], ['N60747', 1], ['N41946', 1], ['N7342', 1], ['N23513', 1], ['N31958', 1], ['N62318', 1], ['N5940', 1], ['N36940', 1], ['N36779', 1], ['N43646', 1], ['N51793', 1], ['N6916', 1], ['N53242', 1], ['N30290', 1], ['N23767', 1], ['N42844', 1], ['N42233', 1], ['N35216', 1], ['N48487', 1], ['N13408', 1], ['N10423', 1], ['N46976', 1], ['N42767', 1], ['N13865', 1], ['N46162', 1], ['N32536', 1], ['N20187', 1], ['N36786', 1], ['N27738', 1], ['N27057', 1], ['N24109', 1], ['N6638', 1], ['N40656', 1], ['N20036', 1], ['N13556', 1], ['N42670', 1]]}
# {'U21693': [['N11930', 1], ['N7419', 1], ['N60747', 1], ['N41946', 1], ['N7342', 1], ['N23513', 1], ['N31958', 1], ['N62318', 1], ['N5940', 1], ['N36940', 1], ['N36779', 1], ['N43646', 1], ['N51793', 1], ['N6916', 1], ['N53242', 1], ['N30290', 1], ['N23767', 1], ['N42844', 1], ['N42233', 1], ['N35216', 1], ['N48487', 1], ['N13408', 1], ['N10423', 1], ['N46976', 1], ['N42767', 1], ['N13865', 1], ['N46162', 1], ['N32536', 1], ['N20187', 1], ['N36786', 1], ['N27738', 1], ['N27057', 1], ['N24109', 1], ['N6638', 1], ['N40656', 1], ['N20036', 1], ['N13556', 1], ['N42670', 1]]}
# 0.0 123 1
# {'U21693': [['N11930', 1], ['N7419', 1], ['N60747', 1], ['N41946', 1], ['N7342', 1], ['N23513', 1], ['N31958', 1], ['N62318', 1], ['N5940', 1], ['N36940', 1], ['N36779', 1], ['N43646', 1], ['N51793', 1], ['N6916', 1], ['N53242', 1], ['N30290', 1], ['N23767', 1], ['N42844', 1], ['N42233', 1], ['N35216', 1], ['N48487', 1], ['N13408', 1], ['N10423', 1], ['N46976', 1], ['N42767', 1], ['N13865', 1], ['N46162', 1], ['N32536', 1], ['N20187', 1], ['N36786', 1], ['N27738', 1], ['N27057', 1], ['N24109', 1], ['N6638', 1], ['N40656', 1], ['N20036', 1], ['N13556', 1], ['N42670', 1]]}
# 0.0 123 1
# 0.0 123 1
# 0.0 123 1
# 0.0 123 1
# {'U21693': [['N11930', 1], ['N7419', 1], ['N60747', 1], ['N41946', 1], ['N7342', 1], ['N23513', 1], ['N31958', 1], ['N62318', 1], ['N5940', 1], ['N36940', 1], ['N36779', 1], ['N43646', 1], ['N51793', 1], ['N6916', 1], ['N53242', 1], ['N30290', 1], ['N23767', 1], ['N42844', 1], ['N42233', 1], ['N35216', 1], ['N48487', 1], ['N13408', 1], ['N10423', 1], ['N46976', 1], ['N42767', 1], ['N13865', 1], ['N46162', 1], ['N32536', 1], ['N20187', 1], ['N36786', 1], ['N27738', 1], ['N27057', 1], ['N24109', 1], ['N6638', 1], ['N40656', 1], ['N20036', 1], ['N13556', 1], ['N42670', 1]]}
# {'U21693': [['N11930', 1], ['N7419', 1], ['N60747', 1], ['N41946', 1], ['N7342', 1], ['N23513', 1], ['N31958', 1], ['N62318', 1], ['N5940', 1], ['N36940', 1], ['N36779', 1], ['N43646', 1], ['N51793', 1], ['N6916', 1], ['N53242', 1], ['N30290', 1], ['N23767', 1], ['N42844', 1], ['N42233', 1], ['N35216', 1], ['N48487', 1], ['N13408', 1], ['N10423', 1], ['N46976', 1], ['N42767', 1], ['N13865', 1], ['N46162', 1], ['N32536', 1], ['N20187', 1], ['N36786', 1], ['N27738', 1], ['N27057', 1], ['N24109', 1], ['N6638', 1], ['N40656', 1], ['N20036', 1], ['N13556', 1], ['N42670', 1]]}
# 0.0 123 1
# 0.0 123 1
# 0.0 123 1
# 0.0 123 1
# 0.0 123 1
# 0.0 123 1
# 0.0 123 1
# {'U21693': [['N11930', 1], ['N7419', 1], ['N60747', 1], ['N41946', 1], ['N7342', 1], ['N23513', 1], ['N31958', 1], ['N62318', 1], ['N5940', 1], ['N36940', 1], ['N36779', 1], ['N43646', 1], ['N51793', 1], ['N6916', 1], ['N53242', 1], ['N30290', 1], ['N23767', 1], ['N42844', 1], ['N42233', 1], ['N35216', 1], ['N48487', 1], ['N13408', 1], ['N10423', 1], ['N46976', 1], ['N42767', 1], ['N13865', 1], ['N46162', 1], ['N32536', 1], ['N20187', 1], ['N36786', 1], ['N27738', 1], ['N27057', 1], ['N24109', 1], ['N6638', 1], ['N40656', 1], ['N20036', 1], ['N13556', 1], ['N42670', 1]]}
# 0.0 123 1
# 0.0 123 1
# {'U21693': [['N11930', 1], ['N7419', 1], ['N60747', 1], ['N41946', 1], ['N7342', 1], ['N23513', 1], ['N31958', 1], ['N62318', 1], ['N5940', 1], ['N36940', 1], ['N36779', 1], ['N43646', 1], ['N51793', 1], ['N6916', 1], ['N53242', 1], ['N30290', 1], ['N23767', 1], ['N42844', 1], ['N42233', 1], ['N35216', 1], ['N48487', 1], ['N13408', 1], ['N10423', 1], ['N46976', 1], ['N42767', 1], ['N13865', 1], ['N46162', 1], ['N32536', 1], ['N20187', 1], ['N36786', 1], ['N27738', 1], ['N27057', 1], ['N24109', 1], ['N6638', 1], ['N40656', 1], ['N20036', 1], ['N13556', 1], ['N42670', 1]]}
# 0.0 123 1
# {'U21693': [['N11930', 1], ['N7419', 1], ['N60747', 1], ['N41946', 1], ['N7342', 1], ['N23513', 1], ['N31958', 1], ['N62318', 1], ['N5940', 1], ['N36940', 1], ['N36779', 1], ['N43646', 1], ['N51793', 1], ['N6916', 1], ['N53242', 1], ['N30290', 1], ['N23767', 1], ['N42844', 1], ['N42233', 1], ['N35216', 1], ['N48487', 1], ['N13408', 1], ['N10423', 1], ['N46976', 1], ['N42767', 1], ['N13865', 1], ['N46162', 1], ['N32536', 1], ['N20187', 1], ['N36786', 1], ['N27738', 1], ['N27057', 1], ['N24109', 1], ['N6638', 1], ['N40656', 1], ['N20036', 1], ['N13556', 1], ['N42670', 1]]}
# 0.0 123 1
# 0.0 123 1
# {'U21693': [['N11930', 1], ['N7419', 1], ['N60747', 1], ['N41946', 1], ['N7342', 1], ['N23513', 1], ['N31958', 1], ['N62318', 1], ['N5940', 1], ['N36940', 1], ['N36779', 1], ['N43646', 1], ['N51793', 1], ['N6916', 1], ['N53242', 1], ['N30290', 1], ['N23767', 1], ['N42844', 1], ['N42233', 1], ['N35216', 1], ['N48487', 1], ['N13408', 1], ['N10423', 1], ['N46976', 1], ['N42767', 1], ['N13865', 1], ['N46162', 1], ['N32536', 1], ['N20187', 1], ['N36786', 1], ['N27738', 1], ['N27057', 1], ['N24109', 1], ['N6638', 1], ['N40656', 1], ['N20036', 1], ['N13556', 1], ['N42670', 1]]}
# 0.0 123 1
# {'U21693': [['N11930', 1], ['N7419', 1], ['N60747', 1], ['N41946', 1], ['N7342', 1], ['N23513', 1], ['N31958', 1], ['N62318', 1], ['N5940', 1], ['N36940', 1], ['N36779', 1], ['N43646', 1], ['N51793', 1], ['N6916', 1], ['N53242', 1], ['N30290', 1], ['N23767', 1], ['N42844', 1], ['N42233', 1], ['N35216', 1], ['N48487', 1], ['N13408', 1], ['N10423', 1], ['N46976', 1], ['N42767', 1], ['N13865', 1], ['N46162', 1], ['N32536', 1], ['N20187', 1], ['N36786', 1], ['N27738', 1], ['N27057', 1], ['N24109', 1], ['N6638', 1], ['N40656', 1], ['N20036', 1], ['N13556', 1], ['N42670', 1]]}
# 0.0 123 1
# {'U21693': [['N11930', 1], ['N7419', 1], ['N60747', 1], ['N41946', 1], ['N7342', 1], ['N23513', 1], ['N31958', 1], ['N62318', 1], ['N5940', 1], ['N36940', 1], ['N36779', 1], ['N43646', 1], ['N51793', 1], ['N6916', 1], ['N53242', 1], ['N30290', 1], ['N23767', 1], ['N42844', 1], ['N42233', 1], ['N35216', 1], ['N48487', 1], ['N13408', 1], ['N10423', 1], ['N46976', 1], ['N42767', 1], ['N13865', 1], ['N46162', 1], ['N32536', 1], ['N20187', 1], ['N36786', 1], ['N27738', 1], ['N27057', 1], ['N24109', 1], ['N6638', 1], ['N40656', 1], ['N20036', 1], ['N13556', 1], ['N42670', 1]]}
# 0.0 123 1
# 0.0 123 1
# 0.0 123 1
# 0.0 123 1
# 0.0 123 1
# 0.0 123 1
# {'U21693': [['N11930', 1], ['N7419', 1], ['N60747', 1], ['N41946', 1], ['N7342', 1], ['N23513', 1], ['N31958', 1], ['N62318', 1], ['N5940', 1], ['N36940', 1], ['N36779', 1], ['N43646', 1], ['N51793', 1], ['N6916', 1], ['N53242', 1], ['N30290', 1], ['N23767', 1], ['N42844', 1], ['N42233', 1], ['N35216', 1], ['N48487', 1], ['N13408', 1], ['N10423', 1], ['N46976', 1], ['N42767', 1], ['N13865', 1], ['N46162', 1], ['N32536', 1], ['N20187', 1], ['N36786', 1], ['N27738', 1], ['N27057', 1], ['N24109', 1], ['N6638', 1], ['N40656', 1], ['N20036', 1], ['N13556', 1], ['N42670', 1]]}
# 0.0 123 1
# {'U21693': [['N11930', 1], ['N7419', 1], ['N60747', 1], ['N41946', 1], ['N7342', 1], ['N23513', 1], ['N31958', 1], ['N62318', 1], ['N5940', 1], ['N36940', 1], ['N36779', 1], ['N43646', 1], ['N51793', 1], ['N6916', 1], ['N53242', 1], ['N30290', 1], ['N23767', 1], ['N42844', 1], ['N42233', 1], ['N35216', 1], ['N48487', 1], ['N13408', 1], ['N10423', 1], ['N46976', 1], ['N42767', 1], ['N13865', 1], ['N46162', 1], ['N32536', 1], ['N20187', 1], ['N36786', 1], ['N27738', 1], ['N27057', 1], ['N24109', 1], ['N6638', 1], ['N40656', 1], ['N20036', 1], ['N13556', 1], ['N42670', 1]]}
# 0.0 123 1
# 0.0 123 1
# {'U21693': [['N11930', 1], ['N7419', 1], ['N60747', 1], ['N41946', 1], ['N7342', 1], ['N23513', 1], ['N31958', 1], ['N62318', 1], ['N5940', 1], ['N36940', 1], ['N36779', 1], ['N43646', 1], ['N51793', 1], ['N6916', 1], ['N53242', 1], ['N30290', 1], ['N23767', 1], ['N42844', 1], ['N42233', 1], ['N35216', 1], ['N48487', 1], ['N13408', 1], ['N10423', 1], ['N46976', 1], ['N42767', 1], ['N13865', 1], ['N46162', 1], ['N32536', 1], ['N20187', 1], ['N36786', 1], ['N27738', 1], ['N27057', 1], ['N24109', 1], ['N6638', 1], ['N40656', 1], ['N20036', 1], ['N13556', 1], ['N42670', 1]]}
# 0.0 123 1
# 0.0 123 1
# 0.0 123 1

# %%
users_profiles
# Out:
# {'U21693': {'sports': 0.0,
#   'video': 0.0,
#   'kids': 0.0,
#   'middleeast': 0.0,
#   'travel': 0.0,
#   'finance': 0.0,
#   'games': 0.0,
#   'news': 0.0,
#   'health': 0.0,
#   'weather': 0.0,
#   'foodanddrink': 0.0,
#   'movies': 0.0,
#   'autos': 0.0,
#   'lifestyle': 0.0,
#   'music': 0.0,
#   'tv': 0.0,
#   'entertainment': 0.0}}

# %%
items_users_saw
# Out:
# {'U21693': ['N11930',
#   'N7419',
#   'N60747',
#   'N41946',
#   'N7342',
#   'N23513',
#   'N31958',
#   'N62318',
#   'N5940',
#   'N36940',
#   'N36779',
#   'N43646',
#   'N51793',
#   'N6916',
#   'N53242',
#   'N30290',
#   'N23767',
#   'N42844',
#   'N42233',
#   'N35216',
#   'N48487',
#   'N13408',
#   'N10423',
#   'N46976',
#   'N42767',
#   'N13865',
#   'N46162',
#   'N32536',
#   'N20187',
#   'N36786',
#   'N27738',
#   'N27057',
#   'N24109',
#   'N6638',
#   'N40656',
#   'N20036',
#   'N13556',
#   'N42670']}
